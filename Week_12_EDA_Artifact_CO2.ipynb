# %% [markdown]
# # ML Modeling, EDA
#
# Prelude
# ---
# Ask `chatGPT` to give me a outline of EDA on this dataset, vehicle's CO2-emission, and answers:
#
# 1. Explore the data types of each column: Check if each column has the right data type (e.g., numeric data should be represented as floats or integers, while categorical data should be represented as strings).
#
# 2. Explore the distribution of numeric variables: Use histograms or boxplots to visualize the distribution of numeric variables such as ENGINESIZE, CYLINDERS, FUELCONSUMPTION_CITY, FUELCONSUMPTION_HWY, FUELCONSUMPTION_COMB, and CO2EMISSIONS. This will help you understand the range, central tendency, and spread of the data.
#
# 3. Explore the relationships between variables: Check if there are any correlations between the variables. You can use scatter plots or correlation matrices to visualize the relationships between variables such as ENGINESIZE, CYLINDERS, FUELCONSUMPTION_CITY, FUELCONSUMPTION_HWY, FUELCONSUMPTION_COMB, and CO2EMISSIONS. This will help you understand which variables are most strongly associated with each other.
#
# 4. Explore categorical variables: Check if there are any categorical variables in the dataset, such as MAKE, MODEL, VEHICLECLASS, TRANSMISSION, and FUELTYPE. You can use bar charts or frequency tables to visualize the distribution of these variables.
#
# 5. Check for outliers: Check if there are any outliers in the dataset, which could potentially skew the results of the model. You can use boxplots or scatter plots to identify any extreme values.
#
# 6. Feature engineering: Consider creating new features based on existing variables in the dataset, such as calculating the average fuel consumption (FUELCONSUMPTION_AVG) or engine displacement (ENGINE_DISPLACEMENT) based on ENGINESIZE and CYLINDERS.
#
#
# Thus let us exploration to the ML modeling journey, follows this schedule.
#
#
#
# Reference
# ---
# 1. [src](https://medium.com/joguei-os-dados/week-3-predicting-co2-emissions-70e554ad2276)
# 2. [Dataset, Kaggle](https://www.kaggle.com/gangliu/oc2emission/tasks), dataset contains information of CO2 emission from cars.
# 3. Statistics, Soul of ML,
#    - Gopal K. Kanji, 100 STATISTICAL TESTS 3rd Edition, Sage Publications, 2006
#    - [Jason Brownlee , 17 Statistical Hypothesis Tests in Python (Cheat Sheet)](https://machinelearningmastery.com/statistical-hypothesis-tests-in-python-cheat-sheet/?utm_source=drip&utm_medium=email&utm_campaign=17+Statistical+Hypothesis+Tests+in+Python+%28Cheat+Sheet%29&utm_content=17+Statistical+Hypothesis+Tests+in+Python+%28Cheat+Sheet%29), comes with examples by Python

# %%
# import packages required

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt

# %matplotlib inline

# %%
## atributing dataset to a dataframe df
file="https://raw.githubusercontent.com/cchuang2009/2022-1/main/Python_IM/2023-2/data/FuelConsumptionCo2.csv"
#df = pd.read_csv('data/FuelConsumptionCo2.csv')
df=pd.read_csv(file)
df.head(2)
# Out:
#    MODELYEAR   MAKE MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0       2014  ACURA   ILX      COMPACT         2.0          4          AS5
# 1       2014  ACURA   ILX      COMPACT         2.4          4           M6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221

# %%
# save data
df.to_csv("CO2_raw.csv",index=0)

# %%
# length of data, type of features 
# No nan data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
# sizes of kinds of uniques in each feature
# "MODELYEAR" coulde be neglicted since only one value there
df.nunique()
# Out:
# MODELYEAR                     1
# MAKE                         39
# MODEL                       663
# VEHICLECLASS                 16
# ENGINESIZE                   45
# CYLINDERS                     7
# TRANSMISSION                 22
# FUELTYPE                      4
# FUELCONSUMPTION_CITY        167
# FUELCONSUMPTION_HWY         118
# FUELCONSUMPTION_COMB        148
# FUELCONSUMPTION_COMB_MPG     43
# CO2EMISSIONS                159
# dtype: int64

# %%
# select numerical columns
num_cols = list(df.select_dtypes(include=['int64','float64']).columns)
# select categorical columns
cat_cols = list(df.select_dtypes(include=['object','category']).columns)
# remove the column MODELYEAR from the numerical columns since it is only one value
num_cols.remove('MODELYEAR')

# %%
# find out the count/value of most freqenency one in certain feature
# count of values mostly in "TRANSMISSION" is 222 and is 'A6'

df['TRANSMISSION'].value_counts().max(), df['TRANSMISSION'].value_counts().idxmax()
# Out:
# (222, 'A6')

# %% [markdown]
# EDA (Exploratory Data Analysis)
# ---
# by Visualization is the best way to observe the data,
# - How many different kinds are there in each feature?
# - What does the data distributed?

# %%
# countplot 
plt.figure(figsize=(20,4))
sns.countplot(x='MODEL', data=df[:40])
plt.xticks(rotation=15);

# %%
num_cols
# Out:
# ['ENGINESIZE',
#  'CYLINDERS',
#  'FUELCONSUMPTION_CITY',
#  'FUELCONSUMPTION_HWY',
#  'FUELCONSUMPTION_COMB',
#  'FUELCONSUMPTION_COMB_MPG',
#  'CO2EMISSIONS']

# %%
cat_cols
# Out:
# ['MAKE', 'MODEL', 'VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE']

# %%
# snippt to find size of key in "string"-like feature
# there are 279 states in the first word in "Model" feature
cat_cols_val=df['MODEL'].values
new_cat_cols_val = [col.split(' ')[0] for col in cat_cols_val]

len(set(new_cat_cols_val))
# Out:
# 279

# %%
# Snippt to map string-like feature to its frequency
MODEL_dict = df['MODEL'].value_counts().to_dict()
#
#set(MODEL_dict.values())
# {1, 2, 3, 4, 5, 6, 8}
df['MODEL_freq_enc'] = df['MODEL'].map(MODEL_dict)

# %% [markdown]
# Visualisation
# ---
# 1. histogram, numerical feature,
# 2. countplot, the frequency, categrorical features
# 3. Relation
#    - corelation matrix, numerical feature
#    - boxplot, categorical feature vs numerical target

# %%
def plot_numeric_distribution(df,num_cols):
    for col in num_cols:
        plt.figure(figsize=(6, 4))
        sns.histplot(df[col], kde=False)
        plt.title(col)
        plt.show()

plot_numeric_distribution(df,num_cols)

# %%
# use bar charts or frequency tables to visualize the distribution of these categorical columns
def plot_categorical_distribution(df,cols,rot=45):
    for col in cols:    
        plt.figure(figsize=(12,4))
        sns.countplot(x=col, data=df)
        plt.title(col)
        plt.xticks(rotation=rot)
        plt.show()
#plot_categorical_distribution(df,cat_cols)
plot_categorical_distribution(df,cat_cols)

# %%
# use boxplots to visualize the relationship between categorical and numerical columns
def plot_categorical_numerical_relationship(df,cat_cols,num_cols):
    for cat_col in cat_cols:
        for num_col in num_cols:
            plt.figure(figsize=(8, 6))
            sns.boxplot(x=cat_col, y=num_col, data=df)
            plt.title(cat_col + ' vs ' + num_col)
            plt.xticks(rotation=45)
            plt.show()

# %%
# Model too noisy to use
plot_categorical_numerical_relationship(df,cat_cols,['CO2EMISSIONS'])

# %%
# correlation between numerical columns
def plot_correlation(df,num_cols):
    plt.figure(figsize=(10, 8))
    sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
    plt.show()
plot_correlation(df,num_cols)

# %% [markdown]
# Feature Encoding
# ---
# Build model, requires "numbers" only; but
# 1. For numerical data: whether and what  is data distributed statistically?
# 2. For categorical data, just encode them into numerical ones; we can use the package, `catgorical_coders`, to make it.
#    - 'one-hot': suppose that feature = `['A','B',...]`, then create new features, `'A','B',...`, set to 1 if data is in 'A',  else 0.
#
# ```
# feature: 'A','B'
# data/.   feature
# 1           A
# 2           1
#             ⬇︎
# data/.   feature    feature_A.  feature_B
# 1           A          1           0
# 2           B          0           1
# ```
#    - LeaveOneOut Encoder, encode by the same category of data but except itself, suitable for feature having outlier.
#
# ```
# import category_encoders as ce
# encoder = ce.LeaveOneOutEncoder(cols=[...])
# encoder.fit(X, y)
# Xt = encoder.transform(X_new)
#
# data/.   X.  y          data/.  X  Xt   y
# 1.       A   10          1      A  20  10   20/1
# 2        A.  20          2      A. 10. 20   10/1
# 3.       B.  20   ➠      3.     B  25. 20   (30+20)/2
# 4.       B.  30          4.     B. 20. 30   (20+20)/2
# 5.       B   20          5.     B. 25. 20   (20+30)/2
# ```
#    - Others, [Beta Target Encoding](https://www.kaggle.com/mmotoki/avito-target-encoding), [Generalized linear mixed model](https://github.com/scikit-learn-contrib/category_encoders)

# %%
features=['ENGINESIZE', 'CYLINDERS', 'FUELCONSUMPTION_CITY', 
       'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB', 
       'FUELCONSUMPTION_COMB_MPG',
        'MAKE','VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE',
        'CO2EMISSIONS']

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in d:\cgu\tools\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: joblib>=1.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: requests>=2.27.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: scipy<2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: schemdraw==0.15 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: sktime!=0.17.1,<0.17.2,>=0.16.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.17.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: numpy<1.24,>=1.21 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: markupsafe>=2.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: xxhash in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: numba>=0.55.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: yellowbrick>=1.4 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: kaleido>=0.2.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: jinja2>=1.2 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: scikit-learn>=1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: tbats>=1.1.3 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (6.6.0)
# Requirement already satisfied: ipython>=5.5.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: nbformat>=4.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: deprecation>=2.1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: lightgbm>=3.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: plotly>=5.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: cloudpickle in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: pyod>=1.0.8 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.0.9)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: psutil>=5.9.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: category-encoders>=2.4.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.6.1)
# Requirement already satisfied: tqdm>=4.62.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: patsy>=0.5.1 in d:\cgu\tools\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in d:\cgu\tools\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in d:\cgu\tools\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: setuptools>=18.5 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: colorama in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: matplotlib-inline in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: traitlets>=4.2 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pygments in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.0)
# Requirement already satisfied: backcall in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: wheel in d:\cgu\tools\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: jsonschema>=2.6 in d:\cgu\tools\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: fastjsonschema in d:\cgu\tools\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jupyter_core in d:\cgu\tools\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\cgu\tools\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: trace-updater>=0.0.8 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.10.2)
# Requirement already satisfied: jupyter-dash>=0.4.2 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\cgu\tools\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in d:\cgu\tools\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: six in d:\cgu\tools\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\cgu\tools\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\cgu\tools\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\cgu\tools\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: deprecated>=1.2.13 in d:\cgu\tools\anaconda3\lib\site-packages (from sktime!=0.17.1,<0.17.2,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: dash-table==5.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\cgu\tools\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,<0.17.2,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: nest-asyncio in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: ansi2html in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: retrying in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: wcwidth in d:\cgu\tools\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\cgu\tools\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->pycaret) (302)
# Requirement already satisfied: click>=5.1 in d:\cgu\tools\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in d:\cgu\tools\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: entrypoints in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: terminado>=0.8.3 in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: prometheus-client in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: argon2-cffi in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: testpath in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: defusedxml in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: bleach in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\cgu\tools\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\cgu\tools\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in d:\cgu\tools\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in d:\cgu\tools\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %%
# model by pycaret
from pycaret.regression import *

# %%
data=df[features]

s = setup(data = data, target = 'CO2EMISSIONS', session_id=123)
# Out:
# <style type="text/css">
# #T_c06fe_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c06fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c06fe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c06fe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c06fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c06fe_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c06fe_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c06fe_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c06fe_row1_col1" class="data row1 col1" >CO2EMISSIONS</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c06fe_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c06fe_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c06fe_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c06fe_row3_col1" class="data row3 col1" >(1067, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c06fe_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c06fe_row4_col1" class="data row4 col1" >(1067, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c06fe_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c06fe_row5_col1" class="data row5 col1" >(746, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c06fe_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c06fe_row6_col1" class="data row6 col1" >(321, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c06fe_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c06fe_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c06fe_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_c06fe_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c06fe_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c06fe_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c06fe_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c06fe_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c06fe_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c06fe_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c06fe_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c06fe_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c06fe_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_c06fe_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c06fe_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_c06fe_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c06fe_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_c06fe_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c06fe_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_c06fe_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c06fe_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_c06fe_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c06fe_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_c06fe_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c06fe_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_c06fe_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c06fe_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_c06fe_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c06fe_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c06fe_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_c06fe_row21_col1" class="data row21 col1" >9d54</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6f7d6 th {
#   text-align: left;
# }
# #T_6f7d6_row0_col0, #T_6f7d6_row1_col0, #T_6f7d6_row1_col1, #T_6f7d6_row1_col2, #T_6f7d6_row1_col3, #T_6f7d6_row1_col4, #T_6f7d6_row1_col5, #T_6f7d6_row1_col6, #T_6f7d6_row2_col0, #T_6f7d6_row2_col1, #T_6f7d6_row2_col2, #T_6f7d6_row2_col3, #T_6f7d6_row2_col4, #T_6f7d6_row2_col5, #T_6f7d6_row2_col6, #T_6f7d6_row3_col0, #T_6f7d6_row3_col1, #T_6f7d6_row3_col2, #T_6f7d6_row3_col3, #T_6f7d6_row3_col4, #T_6f7d6_row3_col5, #T_6f7d6_row3_col6, #T_6f7d6_row4_col0, #T_6f7d6_row4_col1, #T_6f7d6_row4_col2, #T_6f7d6_row4_col3, #T_6f7d6_row4_col4, #T_6f7d6_row4_col5, #T_6f7d6_row4_col6, #T_6f7d6_row5_col0, #T_6f7d6_row5_col1, #T_6f7d6_row5_col2, #T_6f7d6_row5_col3, #T_6f7d6_row5_col4, #T_6f7d6_row5_col5, #T_6f7d6_row5_col6, #T_6f7d6_row6_col0, #T_6f7d6_row6_col1, #T_6f7d6_row6_col2, #T_6f7d6_row6_col3, #T_6f7d6_row6_col4, #T_6f7d6_row6_col5, #T_6f7d6_row6_col6, #T_6f7d6_row7_col0, #T_6f7d6_row7_col1, #T_6f7d6_row7_col2, #T_6f7d6_row7_col3, #T_6f7d6_row7_col4, #T_6f7d6_row7_col5, #T_6f7d6_row7_col6, #T_6f7d6_row8_col0, #T_6f7d6_row8_col1, #T_6f7d6_row8_col2, #T_6f7d6_row8_col3, #T_6f7d6_row8_col4, #T_6f7d6_row8_col5, #T_6f7d6_row8_col6, #T_6f7d6_row9_col0, #T_6f7d6_row9_col1, #T_6f7d6_row9_col2, #T_6f7d6_row9_col3, #T_6f7d6_row9_col4, #T_6f7d6_row9_col5, #T_6f7d6_row9_col6, #T_6f7d6_row10_col0, #T_6f7d6_row10_col1, #T_6f7d6_row10_col2, #T_6f7d6_row10_col3, #T_6f7d6_row10_col4, #T_6f7d6_row10_col5, #T_6f7d6_row10_col6, #T_6f7d6_row11_col0, #T_6f7d6_row11_col1, #T_6f7d6_row11_col2, #T_6f7d6_row11_col3, #T_6f7d6_row11_col4, #T_6f7d6_row11_col5, #T_6f7d6_row11_col6, #T_6f7d6_row12_col0, #T_6f7d6_row12_col1, #T_6f7d6_row12_col2, #T_6f7d6_row12_col3, #T_6f7d6_row12_col4, #T_6f7d6_row12_col5, #T_6f7d6_row12_col6, #T_6f7d6_row13_col0, #T_6f7d6_row13_col1, #T_6f7d6_row13_col2, #T_6f7d6_row13_col3, #T_6f7d6_row13_col4, #T_6f7d6_row13_col5, #T_6f7d6_row13_col6, #T_6f7d6_row14_col0, #T_6f7d6_row14_col1, #T_6f7d6_row14_col2, #T_6f7d6_row14_col3, #T_6f7d6_row14_col4, #T_6f7d6_row14_col5, #T_6f7d6_row14_col6, #T_6f7d6_row15_col0, #T_6f7d6_row15_col1, #T_6f7d6_row15_col2, #T_6f7d6_row15_col3, #T_6f7d6_row15_col4, #T_6f7d6_row15_col5, #T_6f7d6_row15_col6, #T_6f7d6_row16_col0, #T_6f7d6_row16_col1, #T_6f7d6_row16_col2, #T_6f7d6_row16_col3, #T_6f7d6_row16_col4, #T_6f7d6_row16_col5, #T_6f7d6_row16_col6, #T_6f7d6_row17_col0, #T_6f7d6_row17_col1, #T_6f7d6_row17_col2, #T_6f7d6_row17_col3, #T_6f7d6_row17_col4, #T_6f7d6_row17_col5, #T_6f7d6_row17_col6 {
#   text-align: left;
# }
# #T_6f7d6_row0_col1, #T_6f7d6_row0_col2, #T_6f7d6_row0_col3, #T_6f7d6_row0_col4, #T_6f7d6_row0_col5, #T_6f7d6_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6f7d6_row0_col7, #T_6f7d6_row1_col7, #T_6f7d6_row2_col7, #T_6f7d6_row3_col7, #T_6f7d6_row4_col7, #T_6f7d6_row5_col7, #T_6f7d6_row6_col7, #T_6f7d6_row7_col7, #T_6f7d6_row8_col7, #T_6f7d6_row9_col7, #T_6f7d6_row11_col7, #T_6f7d6_row12_col7, #T_6f7d6_row13_col7, #T_6f7d6_row14_col7, #T_6f7d6_row15_col7, #T_6f7d6_row16_col7, #T_6f7d6_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6f7d6_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6f7d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f7d6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6f7d6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6f7d6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6f7d6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6f7d6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6f7d6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6f7d6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6f7d6_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f7d6_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_6f7d6_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_6f7d6_row0_col1" class="data row0 col1" >0.7302</td>
#       <td id="T_6f7d6_row0_col2" class="data row0 col2" >9.4076</td>
#       <td id="T_6f7d6_row0_col3" class="data row0 col3" >2.4200</td>
#       <td id="T_6f7d6_row0_col4" class="data row0 col4" >0.9979</td>
#       <td id="T_6f7d6_row0_col5" class="data row0 col5" >0.0077</td>
#       <td id="T_6f7d6_row0_col6" class="data row0 col6" >0.0026</td>
#       <td id="T_6f7d6_row0_col7" class="data row0 col7" >0.2870</td>
#     </tr>
#     <tr>
#       <th id="T_6f7d6_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_6f7d6_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6f7d6_row1_col1" class="data row1 col1" >2.2899</td>
#       <td id="T_6f7d6_row1_col2" class="data row1 col2" >19.8092</td>
#       <td id="T_6f7d6_row1_col3" class="data row1 col3" >4.2365</td>
#       <td id="T_6f7d6_row1_col4" class="data row1 col4" >0.9953</td>
#       <td id="T_6f7d6_row1_col5" class="data row1 col5" >0.0142</td>
#       <td id="T_6f7d6_row1_col6" class="data row1 col6" >0.0085</td>
#       <td id="T_6f7d6_row1_col7" class="data row1 col7" >0.2350</td>
#     </tr>
#     <tr>
#       <th id="T_6f7d6_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_6f7d6_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_6f7d6_row2_col1" class="data row2 col1" >1.3832</td>
#       <td id="T_6f7d6_row2_col2" class="data row2 col2" >24.7907</td>
#       <td id="T_6f7d6_row2_col3" class="data row2 col3" >4.2848</td>
#       <td id="T_6f7d6_row2_col4" class="data row2 col4" >0.9944</td>
#       <td id="T_6f7d6_row2_col5" class="data row2 col5" >0.0154</td>
#       <td id="T_6f7d6_row2_col6" class="data row2 col6" >0.0051</td>
#       <td id="T_6f7d6_row2_col7" class="data row2 col7" >0.3110</td>
#     </tr>
#     <tr>
#       <th id="T_6f7d6_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_6f7d6_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_6f7d6_row3_col1" class="data row3 col1" >3.3684</td>
#       <td id="T_6f7d6_row3_col2" class="data row3 col2" >31.6072</td>
#       <td id="T_6f7d6_row3_col3" class="data row3 col3" >5.5228</td>
#       <td id="T_6f7d6_row3_col4" class="data row3 col4" >0.9924</td>
#       <td id="T_6f7d6_row3_col5" class="data row3 col5" >0.0247</td>
#       <td id="T_6f7d6_row3_col6" class="data row3 col6" >0.0131</td>
#       <td id="T_6f7d6_row3_col7" class="data row3 col7" >0.9610</td>
#     </tr>
#     <tr>
#       <th id="T_6f7d6_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_6f7d6_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_6f7d6_row4_col1" class="data row4 col1" >3.3851</td>
#       <td id="T_6f7d6_row4_col2" class="data row4 col2" >31.5812</td>
#       <td id="T_6f7d6_row4_col3" class="data row4 col3" >5.5206</td>
#       <td id="T_6f7d6_row4_col4" class="data row4 col4" >0.9924</td>
#       <td id="T_6f7d6_row4_col5" class="data row4 col5" >0.0246</td>
#       <td id="T_6f7d6_row4_col6" class="data row4 col6" >0.0131</td>
#       <td id="T_6f7d6_row4_col7" class="data row4 col7" >0.1090</td>
#     </tr>
#     <tr>
#       <th id="T_6f7d6_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_6f7d6_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_6f7d6_row5_col1" class="data row5 col1" >3.6019</td>
#       <td id="T_6f7d6_row5_col2" class="data row5 col2" >32.4941</td>
#       <td id="T_6f7d6_row5_col3" class="data row5 col3" >5.6049</td>
#       <td id="T_6f7d6_row5_col4" class="data row5 col4" >0.9922</td>
#       <td id="T_6f7d6_row5_col5" class="data row5 col5" >0.0237</td>
#       <td id="T_6f7d6_row5_col6" class="data row5 col6" >0.0138</td>
#       <td id="T_6f7d6_row5_col7" class="data row5 col7" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_6f7d6_level0_row6" class="row_heading
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
best
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %%
# Linear model, fast is its advantage
lr=create_model('lr')
# Out:
# <style type="text/css">
# #T_8d188_row10_col0, #T_8d188_row10_col1, #T_8d188_row10_col2, #T_8d188_row10_col3, #T_8d188_row10_col4, #T_8d188_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8d188">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d188_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8d188_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8d188_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8d188_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8d188_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8d188_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d188_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d188_row0_col0" class="data row0 col0" >3.1541</td>
#       <td id="T_8d188_row0_col1" class="data row0 col1" >23.7486</td>
#       <td id="T_8d188_row0_col2" class="data row0 col2" >4.8733</td>
#       <td id="T_8d188_row0_col3" class="data row0 col3" >0.9935</td>
#       <td id="T_8d188_row0_col4" class="data row0 col4" >0.0193</td>
#       <td id="T_8d188_row0_col5" class="data row0 col5" >0.0123</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d188_row1_col0" class="data row1 col0" >3.6340</td>
#       <td id="T_8d188_row1_col1" class="data row1 col1" >40.5282</td>
#       <td id="T_8d188_row1_col2" class="data row1 col2" >6.3662</td>
#       <td id="T_8d188_row1_col3" class="data row1 col3" >0.9899</td>
#       <td id="T_8d188_row1_col4" class="data row1 col4" >0.0371</td>
#       <td id="T_8d188_row1_col5" class="data row1 col5" >0.0156</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d188_row2_col0" class="data row2 col0" >4.2784</td>
#       <td id="T_8d188_row2_col1" class="data row2 col1" >57.1915</td>
#       <td id="T_8d188_row2_col2" class="data row2 col2" >7.5625</td>
#       <td id="T_8d188_row2_col3" class="data row2 col3" >0.9881</td>
#       <td id="T_8d188_row2_col4" class="data row2 col4" >0.0220</td>
#       <td id="T_8d188_row2_col5" class="data row2 col5" >0.0145</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d188_row3_col0" class="data row3 col0" >2.8582</td>
#       <td id="T_8d188_row3_col1" class="data row3 col1" >30.7426</td>
#       <td id="T_8d188_row3_col2" class="data row3 col2" >5.5446</td>
#       <td id="T_8d188_row3_col3" class="data row3 col3" >0.9917</td>
#       <td id="T_8d188_row3_col4" class="data row3 col4" >0.0307</td>
#       <td id="T_8d188_row3_col5" class="data row3 col5" >0.0113</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d188_row4_col0" class="data row4 col0" >3.9504</td>
#       <td id="T_8d188_row4_col1" class="data row4 col1" >43.4443</td>
#       <td id="T_8d188_row4_col2" class="data row4 col2" >6.5912</td>
#       <td id="T_8d188_row4_col3" class="data row4 col3" >0.9893</td>
#       <td id="T_8d188_row4_col4" class="data row4 col4" >0.0333</td>
#       <td id="T_8d188_row4_col5" class="data row4 col5" >0.0153</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d188_row5_col0" class="data row5 col0" >3.1027</td>
#       <td id="T_8d188_row5_col1" class="data row5 col1" >20.7218</td>
#       <td id="T_8d188_row5_col2" class="data row5 col2" >4.5521</td>
#       <td id="T_8d188_row5_col3" class="data row5 col3" >0.9946</td>
#       <td id="T_8d188_row5_col4" class="data row5 col4" >0.0254</td>
#       <td id="T_8d188_row5_col5" class="data row5 col5" >0.0126</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d188_row6_col0" class="data row6 col0" >2.7005</td>
#       <td id="T_8d188_row6_col1" class="data row6 col1" >24.0832</td>
#       <td id="T_8d188_row6_col2" class="data row6 col2" >4.9075</td>
#       <td id="T_8d188_row6_col3" class="data row6 col3" >0.9923</td>
#       <td id="T_8d188_row6_col4" class="data row6 col4" >0.0164</td>
#       <td id="T_8d188_row6_col5" class="data row6 col5" >0.0103</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8d188_row7_col0" class="data row7 col0" >2.9592</td>
#       <td id="T_8d188_row7_col1" class="data row7 col1" >20.0132</td>
#       <td id="T_8d188_row7_col2" class="data row7 col2" >4.4736</td>
#       <td id="T_8d188_row7_col3" class="data row7 col3" >0.9956</td>
#       <td id="T_8d188_row7_col4" class="data row7 col4" >0.0163</td>
#       <td id="T_8d188_row7_col5" class="data row7 col5" >0.0108</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8d188_row8_col0" class="data row8 col0" >2.9938</td>
#       <td id="T_8d188_row8_col1" class="data row8 col1" >17.5315</td>
#       <td id="T_8d188_row8_col2" class="data row8 col2" >4.1871</td>
#       <td id="T_8d188_row8_col3" class="data row8 col3" >0.9951</td>
#       <td id="T_8d188_row8_col4" class="data row8 col4" >0.0162</td>
#       <td id="T_8d188_row8_col5" class="data row8 col5" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8d188_row9_col0" class="data row9 col0" >4.0531</td>
#       <td id="T_8d188_row9_col1" class="data row9 col1" >38.0667</td>
#       <td id="T_8d188_row9_col2" class="data row9 col2" >6.1698</td>
#       <td id="T_8d188_row9_col3" class="data row9 col3" >0.9935</td>
#       <td id="T_8d188_row9_col4" class="data row9 col4" >0.0307</td>
#       <td id="T_8d188_row9_col5" class="data row9 col5" >0.0163</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8d188_row10_col0" class="data row10 col0" >3.3684</td>
#       <td id="T_8d188_row10_col1" class="data row10 col1" >31.6072</td>
#       <td id="T_8d188_row10_col2" class="data row10 col2" >5.5228</td>
#       <td id="T_8d188_row10_col3" class="data row10 col3" >0.9924</td>
#       <td id="T_8d188_row10_col4" class="data row10 col4" >0.0247</td>
#       <td id="T_8d188_row10_col5" class="data row10 col5" >0.0131</td>
#     </tr>
#     <tr>
#       <th id="T_8d188_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8d188_row11_col0" class="data row11 col0" >0.5326</td>
#       <td id="T_8d188_row11_col1" class="data row11 col1" >12.1907</td>
#       <td id="T_8d188_row11_col2" class="data row11 col2" >1.0517</td>
#       <td id="T_8d188_row11_col3" class="data row11 col3" >0.0025</td>
#       <td id="T_8d188_row11_col4" class="data row11 col4" >0.0074</td>
#       <td id="T_8d188_row11_col5" class="data row11 col5" >0.0021</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# auto-turning parameters
tuned_lr= tune_model(lr)
# Out:
# <style type="text/css">
# #T_001d9_row10_col0, #T_001d9_row10_col1, #T_001d9_row10_col2, #T_001d9_row10_col3, #T_001d9_row10_col4, #T_001d9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_001d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_001d9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_001d9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_001d9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_001d9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_001d9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_001d9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_001d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_001d9_row0_col0" class="data row0 col0" >3.1541</td>
#       <td id="T_001d9_row0_col1" class="data row0 col1" >23.7486</td>
#       <td id="T_001d9_row0_col2" class="data row0 col2" >4.8733</td>
#       <td id="T_001d9_row0_col3" class="data row0 col3" >0.9935</td>
#       <td id="T_001d9_row0_col4" class="data row0 col4" >0.0193</td>
#       <td id="T_001d9_row0_col5" class="data row0 col5" >0.0123</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_001d9_row1_col0" class="data row1 col0" >3.6340</td>
#       <td id="T_001d9_row1_col1" class="data row1 col1" >40.5282</td>
#       <td id="T_001d9_row1_col2" class="data row1 col2" >6.3662</td>
#       <td id="T_001d9_row1_col3" class="data row1 col3" >0.9899</td>
#       <td id="T_001d9_row1_col4" class="data row1 col4" >0.0371</td>
#       <td id="T_001d9_row1_col5" class="data row1 col5" >0.0156</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_001d9_row2_col0" class="data row2 col0" >4.2784</td>
#       <td id="T_001d9_row2_col1" class="data row2 col1" >57.1915</td>
#       <td id="T_001d9_row2_col2" class="data row2 col2" >7.5625</td>
#       <td id="T_001d9_row2_col3" class="data row2 col3" >0.9881</td>
#       <td id="T_001d9_row2_col4" class="data row2 col4" >0.0220</td>
#       <td id="T_001d9_row2_col5" class="data row2 col5" >0.0145</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_001d9_row3_col0" class="data row3 col0" >2.8582</td>
#       <td id="T_001d9_row3_col1" class="data row3 col1" >30.7426</td>
#       <td id="T_001d9_row3_col2" class="data row3 col2" >5.5446</td>
#       <td id="T_001d9_row3_col3" class="data row3 col3" >0.9917</td>
#       <td id="T_001d9_row3_col4" class="data row3 col4" >0.0307</td>
#       <td id="T_001d9_row3_col5" class="data row3 col5" >0.0113</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_001d9_row4_col0" class="data row4 col0" >3.9504</td>
#       <td id="T_001d9_row4_col1" class="data row4 col1" >43.4443</td>
#       <td id="T_001d9_row4_col2" class="data row4 col2" >6.5912</td>
#       <td id="T_001d9_row4_col3" class="data row4 col3" >0.9893</td>
#       <td id="T_001d9_row4_col4" class="data row4 col4" >0.0333</td>
#       <td id="T_001d9_row4_col5" class="data row4 col5" >0.0153</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_001d9_row5_col0" class="data row5 col0" >3.1027</td>
#       <td id="T_001d9_row5_col1" class="data row5 col1" >20.7218</td>
#       <td id="T_001d9_row5_col2" class="data row5 col2" >4.5521</td>
#       <td id="T_001d9_row5_col3" class="data row5 col3" >0.9946</td>
#       <td id="T_001d9_row5_col4" class="data row5 col4" >0.0254</td>
#       <td id="T_001d9_row5_col5" class="data row5 col5" >0.0126</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_001d9_row6_col0" class="data row6 col0" >2.7005</td>
#       <td id="T_001d9_row6_col1" class="data row6 col1" >24.0832</td>
#       <td id="T_001d9_row6_col2" class="data row6 col2" >4.9075</td>
#       <td id="T_001d9_row6_col3" class="data row6 col3" >0.9923</td>
#       <td id="T_001d9_row6_col4" class="data row6 col4" >0.0164</td>
#       <td id="T_001d9_row6_col5" class="data row6 col5" >0.0103</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_001d9_row7_col0" class="data row7 col0" >2.9592</td>
#       <td id="T_001d9_row7_col1" class="data row7 col1" >20.0132</td>
#       <td id="T_001d9_row7_col2" class="data row7 col2" >4.4736</td>
#       <td id="T_001d9_row7_col3" class="data row7 col3" >0.9956</td>
#       <td id="T_001d9_row7_col4" class="data row7 col4" >0.0163</td>
#       <td id="T_001d9_row7_col5" class="data row7 col5" >0.0108</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_001d9_row8_col0" class="data row8 col0" >2.9938</td>
#       <td id="T_001d9_row8_col1" class="data row8 col1" >17.5315</td>
#       <td id="T_001d9_row8_col2" class="data row8 col2" >4.1871</td>
#       <td id="T_001d9_row8_col3" class="data row8 col3" >0.9951</td>
#       <td id="T_001d9_row8_col4" class="data row8 col4" >0.0162</td>
#       <td id="T_001d9_row8_col5" class="data row8 col5" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_001d9_row9_col0" class="data row9 col0" >4.0531</td>
#       <td id="T_001d9_row9_col1" class="data row9 col1" >38.0667</td>
#       <td id="T_001d9_row9_col2" class="data row9 col2" >6.1698</td>
#       <td id="T_001d9_row9_col3" class="data row9 col3" >0.9935</td>
#       <td id="T_001d9_row9_col4" class="data row9 col4" >0.0307</td>
#       <td id="T_001d9_row9_col5" class="data row9 col5" >0.0163</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_001d9_row10_col0" class="data row10 col0" >3.3684</td>
#       <td id="T_001d9_row10_col1" class="data row10 col1" >31.6072</td>
#       <td id="T_001d9_row10_col2" class="data row10 col2" >5.5228</td>
#       <td id="T_001d9_row10_col3" class="data row10 col3" >0.9924</td>
#       <td id="T_001d9_row10_col4" class="data row10 col4" >0.0247</td>
#       <td id="T_001d9_row10_col5" class="data row10 col5" >0.0131</td>
#     </tr>
#     <tr>
#       <th id="T_001d9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_001d9_row11_col0" class="data row11 col0" >0.5326</td>
#       <td id="T_001d9_row11_col1" class="data row11 col1" >12.1907</td>
#       <td id="T_001d9_row11_col2" class="data row11 col2" >1.0517</td>
#       <td id="T_001d9_row11_col3" class="data row11 col3" >0.0025</td>
#       <td id="T_001d9_row11_col4" class="data row11 col4" >0.0074</td>
#       <td id="T_001d9_row11_col5" class="data row11 col5" >0.0021</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 2 candidates, totalling 20 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
final_lr= finalize_model(tuned_lr)
print(final_lr)
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\user\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['ENGINESIZE', 'CYLINDERS',
#                                              'FUELCONSUMPTION_CITY',
#                                              'FUELCONSUMPTION_HWY',
#                                              'FUELCONSUMPTION_COMB',
#                                              'FUELCONSUMPTION_COMB_MPG'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['MAKE', 'VEHICLE...
#                  TransformerWrapper(include=['VEHICLECLASS', 'TRANSMISSION',
#                                              'FUELTYPE'],
#                                     transformer=OneHotEncoder(cols=['VEHICLECLASS',
#                                                                     'TRANSMISSION',
#                                                                     'FUELTYPE'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('rest_encoding',
#                  TransformerWrapper(include=['MAKE'],
#                                     transformer=TargetEncoder(cols=['MAKE'],
#                                                               handle_missing='return_nan'))),
#                 ('actual_estimator', LinearRegression(n_jobs=-1))])

# %%
save_model(final_lr,'Final_lr_2023_4_27')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\user\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['ENGINESIZE', 'CYLINDERS',
#                                               'FUELCONSUMPTION_CITY',
#                                               'FUELCONSUMPTION_HWY',
#                                               'FUELCONSUMPTION_COMB',
#                                               'FUELCONSUMPTION_COMB_MPG'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['MAKE', 'VEHICLE...
#                   TransformerWrapper(include=['VEHICLECLASS', 'TRANSMISSION',
#                                               'FUELTYPE'],
#                                      transformer=OneHotEncoder(cols=['VEHICLECLASS',
#                                                                      'TRANSMISSION',
#                                                                      'FUELTYPE'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['MAKE'],
#                                      transformer=TargetEncoder(cols=['MAKE'],
#                                                                handle_missing='return_nan'))),
#                  ('actual_estimator', LinearRegression(n_jobs=-1))]),
#  'Final_lr_2023_4_27.pkl')

# %%
saved_final_lr= load_model('Final_lr_2023_4_27')
#predict_model(saved_final_cat)
print(saved_final_lr)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\user\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['ENGINESIZE', 'CYLINDERS',
#                                              'FUELCONSUMPTION_CITY',
#                                              'FUELCONSUMPTION_HWY',
#                                              'FUELCONSUMPTION_COMB',
#                                              'FUELCONSUMPTION_COMB_MPG'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['MAKE', 'VEHICLE...
#                  TransformerWrapper(include=['VEHICLECLASS', 'TRANSMISSION',
#                                              'FUELTYPE'],
#                                     transformer=OneHotEncoder(cols=['VEHICLECLASS',
#                                                                     'TRANSMISSION',
#                                                                     'FUELTYPE'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('rest_encoding',
#                  TransformerWrapper(include=['MAKE'],
#                                     transformer=TargetEncoder(cols=['MAKE'],
#                                                               handle_missing='return_nan'))),
#                 ('actual_estimator', LinearRegression(n_jobs=-1))])

# %%
# !pip install --upgrade pycaret

# !pip install catboost
# Out:
# Requirement already satisfied: pycaret in d:\cgu\tools\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: deprecation>=2.1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: tqdm>=4.62.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: joblib>=1.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (6.6.0)
# Requirement already satisfied: tbats>=1.1.3 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: sktime!=0.17.1,<0.17.2,>=0.16.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.17.0)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: scikit-learn>=1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: xxhash in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: kaleido>=0.2.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: nbformat>=4.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: markupsafe>=2.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: jinja2>=1.2 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: schemdraw==0.15 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: yellowbrick>=1.4 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: psutil>=5.9.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: requests>=2.27.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: lightgbm>=3.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: scipy<2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: ipython>=5.5.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: cloudpickle in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: numba>=0.55.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: category-encoders>=2.4.0 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (2.6.1)
# Requirement already satisfied: pyod>=1.0.8 in d:\cgu\tools\anaconda3\lib\site-packages (from pycaret) (1.0.9)
# Requirement already satisfied: patsy>=0.5.1 in d:\cgu\tools\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in d:\cgu\tools\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in d:\cgu\tools\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: backcall in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: pickleshare in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: pygments in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.0)
# Requirement already satisfied: setuptools>=18.5 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: decorator in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: colorama in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: matplotlib-inline in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in d:\cgu\tools\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\cgu\tools\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: wheel in d:\cgu\tools\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fastjsonschema in d:\cgu\tools\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\cgu\tools\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: jupyter_core in d:\cgu\tools\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\cgu\tools\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.10.2)
# Requirement already satisfied: trace-updater>=0.0.8 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: jupyter-dash>=0.4.2 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: urllib3 in d:\cgu\tools\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\cgu\tools\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: six in d:\cgu\tools\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\cgu\tools\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\cgu\tools\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\cgu\tools\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: deprecated>=1.2.13 in d:\cgu\tools\anaconda3\lib\site-packages (from sktime!=0.17.1,<0.17.2,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: dash-table==5.0.0 in d:\cgu\tools\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\cgu\tools\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,<0.17.2,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: nest-asyncio in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: ansi2html in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: retrying in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: wcwidth in d:\cgu\tools\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\cgu\tools\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->pycaret) (302)
# Requirement already satisfied: itsdangerous>=0.24 in d:\cgu\tools\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=5.1 in d:\cgu\tools\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (7.1.2)
# Requirement already satisfied: entrypoints in d:\cgu\tools\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: argon2-cffi in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: prometheus-client in d:\cgu\tools\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: bleach in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: defusedxml in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: testpath in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in d:\cgu\tools\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\cgu\tools\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\cgu\tools\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\cgu\tools\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in d:\cgu\tools\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in d:\cgu\tools\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Requirement already satisfied: catboost in d:\cgu\tools\anaconda3\lib\site-packages (1.2)
# Requirement already satisfied: pandas>=0.24 in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (1.4.4)
# Requirement already satisfied: plotly in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: matplotlib in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (3.5.2)
# Requirement already satisfied: graphviz in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: scipy in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (1.9.1)
# Requirement already satisfied: numpy>=1.16.0 in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: six in d:\cgu\tools\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\cgu\tools\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2022.1)
# Requirement already satisfied: cycler>=0.10 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\cgu\tools\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in d:\cgu\tools\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %%
# catboost
catboost = create_model('catboost')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9264\258810212.py in <module>
#       1 # catboost
# ----> 2 catboost = create_model('catboost')
#
# D:\CGU\tools\Anaconda3\lib\site-packages\pycaret\utils\generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# D:\CGU\tools\Anaconda3\lib\site-packages\pycaret\regression\functional.py in create_model(estimator, fold, round, cross_validation, fit_kwargs, groups, experiment_custom_tags, engine, verbose, return_train_score, **kwargs)
#     996     """
#     997
# --> 998     return _CURRENT_EXPERIMENT.create_model(
#     999         estimator=estimator,
#    1000         fold=fold,
#
# D:\CGU\tools\Anaconda3\lib\site-packages\pycaret\regression\oop.py in create_model(self, estimator, fold, round, cross_validation, fit_kwargs, groups, experiment_custom_tags, engine, verbose, return_train_score, **kwargs)
#    1291
#    1292         try:
# -> 1293             return_values = super().create_model(
#    1294                 estimator=estimator,
#    1295                 fold=fold,
#
# D:\CGU\tools\Anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, return_train_score, **kwargs)
#    1749             for x in kwargs
#    1750         )
# -> 1751         return self._create_model(
#    1752             estimator=estimator,
#    1753             fold=fold,
#
# D:\CGU\tools\Anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in _create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, **kwargs)
#    1325         if isinstance(estimator, str):
#    1326             if estimator not in available_estimators:
# -> 1327                 raise ValueError(
#    1328                     f"Estimator {estimator} not available. Please see docstring for list of available estimators."
#    1329                 )
#
# ValueError: Estimator catboost not available. Please see docstring for list of available estimators.

# %%
tuned_cat = tune_model(catboost)

# %%
predict_model(tuned_cat)

# %%
final_cat = finalize_model(tuned_cat)
print(final_cat)

# %%
save_model(final_cat,'Final_cat_2023_4_25')

# %% [markdown]
# IMPORTANT NOTE
# ---
# Unlike done in "Linear Regression" case, load "cat_model" is not in "Pipeline" mode.
#
# What is the difference between "Model" and "Pipeline mode"?
# ```
# BY chatGPT
# ---
# In summary:
#
# a model is a single algorithm that makes predictions on new data,
# while a pipeline is a series of data processing steps that can include one or more models, used to transform the input data into a desired output. "Pipeline mode" refers specifically to the use of multiple models in a pipeline.
# ```
#
# This is an issue or feature of Pycaret: cound not use pycaret to "catboost" model. Use `pickle` to take over:

# %%
# loading library
import pickle
# create an iterator object with write permission - model.pkl
with open('model_pkl', 'wb') as files:
    pickle.dump(final_cat, files)
#with open('model_pkl' , 'rb') as f:
#    lr = pickle.load(f)

# %%
saved_final_cat = load_model('model_pkl')
print(saved_final_cat)

# %%
# interpret summary model
interpret_model(saved_final_cat, plot = 'summary')

# %% [markdown]
# Streamlit Artifact
# ---
# 1. Create UI for input
# 2. Predict and display output:
#
# ```
# import streamlit as st
# import numpy as np
# import pandas as pd
#
# from pycaret.regression import load_model, predict_model,setup
#
# file="https://raw.githubusercontent.com/cchuang2009/2022-1/main/Python_IM/2023-2/data/FuelConsumptionCo2.csv"
#
# df = pd.read_csv(file)
#
# num_cols=['ENGINESIZE', 'CYLINDERS','FUELCONSUMPTION_CITY','FUELCONSUMPTION_HWY',\
#           'FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG']
# cat_cols=['MAKE','VEHICLECLASS','TRANSMISSION','FUELTYPE']
# target=['CO2EMISSIONS']
# ```
# ```
# model_cat = load_model('model_pkl')
# st.title('CO2 Emission of Vehicles')
#
# st.markdown("## 汽車二氧化碳排放量")
# st.subheader('CO2 Emission of Vehicle')
#
# features = num_cols + cat_cols
#
# # for num_cols
# col_values = []
# for col in num_cols:
#     col_value = st.slider(col, min_value=float(df[col].min()), max_value=float(df[col].max()), value=float(df[col].median()))
#     col_values.append(col_value)
# num_values = [col_value for col_value in col_values if isinstance(col_value, (int, float))]
#
# # for cat_cols
# cat_values = []
# for col in cat_cols:
#     ops = list(df[col].unique())
#     cat_value = st.selectbox(col, options=ops, index=0)
#     cat_values.append(cat_value)
# cat_values = [cat_value for cat_value in cat_values if isinstance(cat_value, str)]
#
# final_features = np.array(num_values + cat_values).reshape(1, -1)
# ```
# ```
# if st.button('Estimate'):
#     new_data=pd.DataFrame(data=final_features,columns=num_cols + cat_cols)
#     prediction=predict_model(estimator=model_cat, data=new_data)
#     st.balloons()
#     result=int(prediction['prediction_label'][0])
#     st.success(
#         f' Estimated CO2 Emission is {result}')
#
# ```
#
# [Artifact](https://github.com/cchuang2009/2022-1/blob/main/Python_IM/2023-2/CO2.png)
#
# <img src="CO2.png" width=70% />

# %%
https://www.solutionfun.info/landingpage/7f3c2cc9-47a0-4db6-b493-16eedddaeab2/frcCOgf_b5GvN2be-XIufT_40g2KGHkXWUo_f7MkGNU
